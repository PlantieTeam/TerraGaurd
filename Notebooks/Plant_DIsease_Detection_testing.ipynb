# %%
import tensorflow as tf
from  tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
from zipfile import ZipFile
file_name = "smaple_data/Model.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-92f552257d45> in <cell line: 4>()
#       2 file_name = "smaple_data/Model.zip"
#       3
# ----> 4 with ZipFile(file_name, 'r') as zip:
#       5   zip.extractall()
#       6   print('Done')
#
# /usr/lib/python3.10/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1249             while True:
#    1250                 try:
# -> 1251                     self.fp = io.open(file, filemode)
#    1252                 except OSError:
#    1253                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'smaple_data/Model.zip'

# %%
from tensorflow.keras.models import load_model
model_path = "/content/drive/MyDrive/Models/model"
model = load_model(model_path)

# %%
class_names = ['Eggplant - Epilachna Beetle',
 'Eggplant - Flea Beetle',
 'Eggplant - Healthy',
 'Eggplant - Jassid',
 'Eggplant - Mite',
 'Eggplant - Mite and Epilachna Beetle',
 'Eggplant - Nitrogen Deficiency',
 'Eggplant - Nitrogen and Potassium Deficiency',
 'Eggplant - Potassium Deficiency',
 'Pepper__bell___Bacterial_spot',
 'Pepper__bell___healthy',
 'Potato___Early_blight',
 'Potato___Late_blight',
 'Potato___healthy']

# %%
import cv2
image = cv2.imread("/content/drive/MyDrive/Models/Potato___Early_blight.JPG", cv2.COLOR_BGR2RGB)
# image = cv2.cvtColor(image , cv2.COLOR_BAYER_BG2BGR)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image = cv2.resize(image, (220,220))
plt.imshow(image)

# %%
import numpy as np
arr = np.array([image])
prop = model.predict([arr])
# Out:
# 1/1 [==============================] - 0s 330ms/step

# %%
prop
# Out:
# array([[5.5465752e-09, 3.3731316e-16, 1.4811407e-17, 6.3140458e-14,
#         1.1180284e-16, 1.1355923e-11, 3.4791214e-14, 1.5264698e-14,
#         1.1933374e-13, 8.2292714e-11, 1.4155737e-19, 9.9999893e-01,
#         1.0387637e-06, 8.6935761e-24]], dtype=float32)

# %%
pred =np.argmax(prop, axis=1)

# %%
pred
# Out:
# array([11])

# %%
class_names[pred[0]]
# Out:
# 'Potato___Early_blight'
